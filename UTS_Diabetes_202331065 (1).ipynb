# %% [markdown]
# **NAMA : ANJELI RIZKI SYAMIAPUTRI**
#
# **NIM : 202331065**
#
# **UTS_MACHINE LEARNING D**

# %%
import pandas as pd

# %%
dataset = pd.read_csv("K02_diabetes.csv")

# %% [markdown]
# menampilkan atau membaca dataset dengan pd.read_csv

# %%
dataset
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# menampilkan dataset asli yang sudah ditambahkan.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# menampilkan info dari dataframe.

# %%
dataset.gender.unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %% [markdown]
# menampilkan jenis kelamin yang ada didalam dataset

# %%
dataset.age.unique()
# Out:
# array([80.  , 54.  , 28.  , 36.  , 76.  , 20.  , 44.  , 79.  , 42.  ,
#        32.  , 53.  , 78.  , 67.  , 15.  , 37.  , 40.  ,  5.  , 69.  ,
#        72.  ,  4.  , 30.  , 45.  , 43.  , 50.  , 41.  , 26.  , 34.  ,
#        73.  , 77.  , 66.  , 29.  , 60.  , 38.  ,  3.  , 57.  , 74.  ,
#        19.  , 46.  , 21.  , 59.  , 27.  , 13.  , 56.  ,  2.  ,  7.  ,
#        11.  ,  6.  , 55.  ,  9.  , 62.  , 47.  , 12.  , 68.  , 75.  ,
#        22.  , 58.  , 18.  , 24.  , 17.  , 25.  ,  0.08, 33.  , 16.  ,
#        61.  , 31.  ,  8.  , 49.  , 39.  , 65.  , 14.  , 70.  ,  0.56,
#        48.  , 51.  , 71.  ,  0.88, 64.  , 63.  , 52.  ,  0.16, 10.  ,
#        35.  , 23.  ,  0.64,  1.16,  1.64,  0.72,  1.88,  1.32,  0.8 ,
#         1.24,  1.  ,  1.8 ,  0.48,  1.56,  1.08,  0.24,  1.4 ,  0.4 ,
#         0.32,  1.72,  1.48])

# %% [markdown]
# menampilkan umur dari kesuluruhan dataset yang ada.

# %%
dataset.hypertension.unique()
# Out:
# array([0, 1])

# %% [markdown]
# menampilkan nilai-nilai unik yang ada didalam kolom hypertension dataset.

# %%
dataset.heart_disease.unique()
# Out:
# array([1, 0])

# %% [markdown]
# menampilkan nilai-nilai unik yang ada didalam kolom heart_disease dataset.

# %%
dataset.smoking_history.unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %% [markdown]
# menampilkan data-data unik yang ada dikolom smoking_history dataset.

# %%
dataset.bmi.unique()
# Out:
# array([25.19, 27.32, 23.45, ..., 59.42, 44.39, 60.52])

# %% [markdown]
# menampilkan nilai-nilai unik yang ada dikolom bmi dataset.

# %%
dataset.HbA1c_level.unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %% [markdown]
# mendapatkan nilai-nilai unik dalam kolom HbA1c_level dalam dataset.

# %%
dataset.blood_glucose_level.unique()
# Out:
# array([140,  80, 158, 155,  85, 200, 145, 100, 130, 160, 126, 159,  90,
#        260, 220, 300, 280, 240])

# %% [markdown]
# menampilkan nilai-nilai unik dalam blood_glucose_level dalam dataset

# %%
dataset.diabetes.unique()
# Out:
# array([0, 1])

# %% [markdown]
# menampilkan nilai-nilai unik dalam kolom diabetes didalam dataset seperti apakah mereka memiliki diabetes atau tidak jika tidak 0 dan ya 1.

# %%
dataset.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# describe adalah metode yang digunakan untuk menghasilkan statistik deskriptif dari kolom-kolom numerik dalam dataset dan memberikan data gambaran umum tenteng distribusi data.

# %% [markdown]
# # **preprocessing data**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#mengubah calues kolom yang bertipe string/object menjadi numerik

for col in ['gender','smoking_history']:
  label_encoder = LabelEncoder()
  dataset[col] = label_encoder.fit_transform(dataset[col])

# %%
dataset #menampilkan dataset yang sudah diubah menjadi numerik
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %%
x = dataset.drop(['diabetes'],axis=1)
y = dataset["diabetes"]

# %% [markdown]
# x= dataset.drop(['diabetes'],axis=1) = menghapus kolom diabetes dari tadaset dan menyimpanya dalam x, yang akan berisi semua fitur.
#
# y= dataset["diabetes"] : menyimpan kolom diabetes sebagai target variabel y yang ingin diprediksi.
#
# x berisi fitur untuk model dan y berisi target untuk prediksi.

# %%
x
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
dataset
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                0  27.32
# 99996       0   2.0             0              0                0  17.37
# 99997       1  66.0             0              0                3  27.83
# 99998       0  24.0             0              0                4  35.42
# 99999       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# ...

# %% [markdown]
# # **splitting data**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.50)

# %% [markdown]
# membagi dataset menjadi 2 bagian yaitu satu untuk pelatihan dan sagtunya untuk pengujian. size 0.50 berarti 50% data pengujian. data pelatihan disimpan dalam x_train dan y_train, sedangkan data pengujian disimpan dalam x_test dan y_test

# %%
x_train.shape
# Out:
# (50000, 8)

# %% [markdown]
# mengembalikan dimensi dari dataset x_train dalam bentuk tuple: jumlah baris dan jumlah kolom.

# %%
y_train.shape
# Out:
# (50000,)

# %% [markdown]
# mengembalikkan dimensi dari dataset y_train yaitu jumlah elemen (sampel) dalam data target pelatihan.

# %%
y_test.shape
# Out:
# (50000,)

# %% [markdown]
# mengembalikan jumlah elemen dalam data target pengujian yaitu jumlah sample yang diprediksi

# %%
x_test.shape
# Out:
# (50000, 8)

# %% [markdown]
# mengembalikan dimensi data fitur pengujian, yaitu jumlah sampel dan fitur.

# %% [markdown]
# # **modelling data**

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# gaussianNB membuat model klasifikasi menggunakan naive bayes dengan distribusi gausian. dan melatih model dengan data pelatihan x_train (fitur) dan y_train(target).

# %%
hasil_prediksi = model.predict(x_test)

# %% [markdown]
# memprediksi label (target) untuk pengujian x_test

# %%
from sklearn.metrics import accuracy_score
print('akurasi model:', accuracy_score(y_test,hasil_prediksi))
# Out:
# akurasi model: 0.90346

# %% [markdown]
# menghitung akurasi model dengan membandingkan prediksi hasil_prediksi dengan label asli y_test

# %%
pasien_baru =([[1,40,0,0,5,5,6,199]])

# %%
hasilpredisipasien = model.predict(pasien_baru)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# memprediksi apakah pasien baru tersebut memiliki penyakit berdasarkan fitur yang diberikan.

# %%
print(hasilpredisipasien)
# Out:
# [0]

# %% [markdown]
# menampilkan hasil prediksi untuk pasien baru.
